# %%
import pandas as pd

# %%
data = {
    "name": ["Bill", "Tom", "Tim", "John", "Alex", "Vanessa", "Kate"],
    "score": [90, 80, 85, 75, 95, 60, 65],
    "sport": ["Wrestling", "Football", "Skiing", "Swimming", "Tennis", "Karate", "Surfing"],
    "gender": ["M", "M", "M", "M", "F","F", "F"]
}

df = pd.DataFrame(data)
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karate      F
# 6     Kate     65    Surfing      F

# %%
interested_col_df = df[["name", "score", "sport"]]
interested_col_df
# Out:
#       name  score      sport
# 0     Bill     90  Wrestling
# 1      Tom     80   Football
# 2      Tim     85     Skiing
# 3     John     75   Swimming
# 4     Alex     95     Tennis
# 5  Vanessa     60     Karate
# 6     Kate     65    Surfing

# %%
df.head(5)
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M
# 3  John     75   Swimming      M
# 4  Alex     95     Tennis      F

# %%
df.tail(5)
# Out:
#       name  score     sport gender
# 2      Tim     85    Skiing      M
# 3     John     75  Swimming      M
# 4     Alex     95    Tennis      F
# 5  Vanessa     60    Karate      F
# 6     Kate     65   Surfing      F

# %%
df.sample(n=3, random_state=42)
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 5  Vanessa     60     Karate      F

# %%
df.describe()
# Out:
#            score
# count   7.000000
# mean   78.571429
# std    12.817399
# min    60.000000
# 25%    70.000000
# 50%    80.000000
# 75%    87.500000
# max    95.000000

# %%
df.columns
# Out:
# Index(['name', 'score', 'sport', 'gender'], dtype='object')

# %%
print(df.loc[2])
print("-------------------------")
print(df.iloc[1:4, 0:2])
# Out:
# name         Tim
# score         85
# sport     Skiing
# gender         M
# Name: 2, dtype: object
# -------------------------
#    name  score
# 1   Tom     80
# 2   Tim     85
# 3  John     75

# %%
df.set_index("name", inplace=True)
df
# Out:
#          score      sport gender
# name
# Bill        90  Wrestling      M
# Tom         80   Football      M
# Tim         85     Skiing      M
# John        75   Swimming      M
# Alex        95     Tennis      F
# Vanessa     60     Karate      F
# Kate        65    Surfing      F

# %%
df.reset_index(inplace=True)
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karate      F
# 6     Kate     65    Surfing      F

# %%
df.set_index("name", inplace=True)

# %%
print(df.loc["Bill"])
print("-----------------------")
print(df.iloc[1, 2])
print("-----------------------")
print(df.iloc[1, [0, 2]])
# Out:
# score            90
# sport     Wrestling
# gender            M
# Name: Bill, dtype: object
# -----------------------
# M
# -----------------------
# score     80
# gender     M
# Name: Tom, dtype: object

# %%
print(df.loc["Bill": "Tom", "score": "gender"])
print("---------iloc------------")
print(df.iloc[1:3, 0:2])
# Out:
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tom      80   Football      M
# ---------iloc------------
#       score     sport
# name
# Tom      80  Football
# Tim      85    Skiing

# %%
print(df["gender"] == "M")
df[df["gender"] == "M"]
# Out:
# name
# Bill        True
# Tom         True
# Tim         True
# John        True
# Alex       False
# Vanessa    False
# Kate       False
# Name: gender, dtype: bool
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tom      80   Football      M
# Tim      85     Skiing      M
# John     75   Swimming      M

# %%
print(df[(df["score"] > 80) & (df["gender"] == "M")])
print("-----------------------")
print(df[((df["sport"] > "Wrestling") | (df["sport"] == "Swimming")) & (df["score"] > 70)])
# Out:
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tim      85     Skiing      M
# -----------------------
#       score     sport gender
# name
# John     75  Swimming      M

# %%
print(df.sort_values("score", ascending=False))
# Out:
#          score      sport gender
# name
# Alex        95     Tennis      F
# Bill        90  Wrestling      M
# Tim         85     Skiing      M
# Tom         80   Football      M
# John        75   Swimming      M
# Kate        65    Surfing      F
# Vanessa     60     Karate      F

# %%
print(df.sort_values(["gender", "score"], ascending=[True, False]))
# Out:
#          score      sport gender
# name
# Alex        95     Tennis      F
# Kate        65    Surfing      F
# Vanessa     60     Karate      F
# Bill        90  Wrestling      M
# Tim         85     Skiing      M
# Tom         80   Football      M
# John        75   Swimming      M
