# %%
import pandas as pd

# %%
data = [1, 2, 3, 4, 5]
s = pd.Series(data)

print(type(s))

print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#Custom index

labelled_data = pd.Series([1, "Nijesh", "Sankhu", 21], index=["Index", "Name", "Address", "Age"])

labelled_data
# Out:
# Index           1
# Name       Nijesh
# Address    Sankhu
# Age            21
# dtype: object

# %%
labelled_data["Age"]
# Out:
# 21

# %%
score = {"Name": "Nijesh", "Address": "Sankhu", "Age": 21}
details = pd.Series(score)

details
# Out:
# Name       Nijesh
# Address    Sankhu
# Age            21
# dtype: object

# %%
details[details == 21]
# Out:
# Age    21
# dtype: object

# %%
details[details == "Nijesh"] = "Anish"
details[details == "Anish"]
# Out:
# Name    Anish
# dtype: object

# %%
"Name" in details

if "Name" in details:
    print(f"What's up {details["Name"]}")
else:
    print("Nothing")
# Out:
# What's up Anish

# %%
#Handling none or nan values

import numpy as np

# %%
data = pd.Series([1, 2, 3, np.nan, 4, 5])
data.mean(skipna=True)
# Out:
# np.float64(3.0)

# %%
score={"Jone": 90, "Bill": 80, "Elon": 85, "Tom": np.nan, "Tim": 95, "Gp": None}
names = pd.Series(score)
names
# Out:
# Jone    90.0
# Bill    80.0
# Elon    85.0
# Tom      NaN
# Tim     95.0
# Gp       NaN
# dtype: float64

# %%
names.isnull()
# Out:
# Jone    False
# Bill    False
# Elon    False
# Tom      True
# Tim     False
# Gp       True
# dtype: bool

# %%
names.isna()
# Out:
# Jone    False
# Bill    False
# Elon    False
# Tom      True
# Tim     False
# Gp       True
# dtype: bool

# %%
names.isna().any()
# Out:
# np.True_

# %%
names_without_na = names.dropna(inplace=False)

names_without_na
# Out:
# Jone    90.0
# Bill    80.0
# Elon    85.0
# Tim     95.0
# dtype: float64

# %%
names["gagan"] = np.nan

# %%
names.fillna(10, inplace=True)
names
# Out:
# Jone     90.0
# Bill     80.0
# Elon     85.0
# Tom      10.0
# Tim      95.0
# Gp       10.0
# gagan    10.0
# dtype: float64
